# %% [markdown]
# # **Deepface**

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']

# %%
img = cv2.imread("selfie.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

faces = DeepFace.extract_faces(img_path="/home/pawan/Dev/Computer-Vision-Projects/Deepface/selfie.jpeg", detector_backend="opencv")

for idx, face in enumerate(faces):
    plt.figure()
    plt.imshow(face["face"])
    plt.title(f"Detected Face {idx+1}")
    plt.axis('off')
    plt.show()

# %%
# Analyze emotion from an image using DeepFace
emotion_result = DeepFace.analyze(img_path="/home/pawan/Dev/Computer-Vision-Projects/Deepface/selfie.jpeg", actions=['emotion'])
print("Detected emotion:", emotion_result[0]['emotion'])
# Out:
# Detected emotion: {'angry': 0.0031444749765796587, 'disgust': 2.7696572994589073e-12, 'fear': 0.04343861364759505, 'happy': 6.26064206699084e-05, 'sad': 0.02207991055911407, 'surprise': 0.0021615594960167073, 'neutral': 99.9291181564331}

# %%
objs = DeepFace.analyze(
  img_path = "selfie.jpeg", actions = ['age', 'gender', 'race', 'emotion']
  ) 
objs  # Print the analysis results
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:16<00:00,  4.08s/it]
# [{'age': 29,
#   'region': {'x': 116,
#    'y': 483,
#    'w': 286,
#    'h': 286,
#    'left_eye': (311, 595),
#    'right_eye': (203, 594)},
#   'face_confidence': 0.91,
#   'gender': {'Woman': 0.14436576748266816, 'Man': 99.85563158988953},
#   'dominant_gender': 'Man',
#   'race': {'asian': 2.794505077272956,
#    'indian': 61.575780008779766,
#    'black': 7.869693360906443,
#    'white': 2.852257697418791,
#    'middle eastern': 3.931391846024504,
#    'latino hispanic': 20.976377783797847},
#   'dominant_race': 'indian',
#   'emotion': {'angry': 0.0031444749765796587,
#    'disgust': 2.7696572994589073e-12,
#    'fear': 0.04343861364759505,
#    'happy': 6.26064206699084e-05,
#    'sad': 0.02207991055911407,
#    'surprise': 0.0021615594960167073,
#    'neutral': 99.9291181564331},
#   'dominant_emotion': 'neutral'}]

# %% [markdown]
# **Emotion detection using deepface on live feed**

# %%
import cv2
from deepface import DeepFace

cap = cv2.VideoCapture(0)  # 0 for default webcam

while True:
    ret, frame = cap.read()
    if not ret:
        break
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        emotion = result[0]['dominant_emotion'] if isinstance(result, list) else result['dominant_emotion']
        cv2.putText(frame, f"Emotion: {emotion}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
    except Exception as e:
        cv2.putText(frame, "No face detected", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

    cv2.imshow('DeepFace Live Feed', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2908, resource id: 23068672, major code: 18 (ChangeProperty), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2909, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2910, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2911, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2912, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2915, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# qt.qpa.xcb: QXcbConnection: XCB error: 3 (BadWindow), sequence: 2918, resource id: 23068672, major code: 25 (SendEvent), minor code: 0
# ...
